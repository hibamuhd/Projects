# %%
import pandas as pd

# %%
ikea = pd.read_csv('ikea.csv', sep=',')
ikea
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
ikea['InvoiceDate'] = pd.to_datetime(ikea['InvoiceDate'], dayfirst=True)
ikea['invoice_dt'] = ikea['InvoiceDate'].dt.date
ikea['time'] = ikea['InvoiceDate'].dt.time

# %%
ikea
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  invoice_dt  \
# ...

# %%
ikea = ikea.drop(columns=['InvoiceDate'])

# %%
ikea.columns = ['invoiceno', 'stockcode', 'desc', 'quantity', 'unitprice', 'custid', 'country', 'date', 'time']
ikea['custid'] = ikea['custid'].fillna(0)
ikea = ikea[['invoiceno', 'date', 'time', 'stockcode', 'desc', 'quantity', 'unitprice', 'custid', 'country']]

# %%
ikea
# Out:
#        invoiceno        date      time stockcode  \
# 0         536365  2010-12-01  08:26:00    85123A
# 1         536365  2010-12-01  08:26:00     71053
# 2         536365  2010-12-01  08:26:00    84406B
# 3         536365  2010-12-01  08:26:00    84029G
# 4         536365  2010-12-01  08:26:00    84029E
# ...          ...         ...       ...       ...
# 541904    581587  2011-12-09  12:50:00     22613
# 541905    581587  2011-12-09  12:50:00     22899
# 541906    581587  2011-12-09  12:50:00     23254
# 541907    581587  2011-12-09  12:50:00     23255
# 541908    581587  2011-12-09  12:50:00     22138
#
#                                        desc  quantity  unitprice   custid  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6       2.55  17850.0
# 1                       WHITE METAL LANTERN         6       3.39  17850.0
# 2            CREAM CUPID HEARTS COAT HANGER         8       2.75  17850.0
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6       3.39  17850.0
# ...

# %%
ikea.to_csv('ikea_updated.csv')
